# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Deep Learning/Object Detection/Number-Plate
# Out:
# /content/drive/MyDrive/Deep Learning/Object Detection/Number-Plate

# %%
# !git init
# !git config --global user.email "aniket.iitism@gmail.com"
# !git config --global user.name "dwivedi1997"
# !git add .
# !git commit -m 'Initial Commit'
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/Deep Learning/Object Detection/Number-Plate/.git/
# ...
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> sort
# hint:
# hint: If you added this path by mistake, you can remove it from the
# ...

# %%
# !git remote set-url origin 'https://dwivedi1997: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@github.com/dwivedi1997/Number-Plate-Detection.git'

# %%
# !git push -u origin main
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://github.com/dwivedi1997/Number-Plate-Detection.git/'

# %%
# !git branch
# Out:
# * main
#   master

# %%
# !git checkout -b main
# Out:
# Switched to a new branch 'main'

# %%
# !git add .
# !git commit -m "Initial commit"
# Out:
# [main 83b69ce] Initial commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite git_push.ipynb (88%)

# %%
# !git push -u origin main
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://github.com/dwivedi1997/Number-Plate-Detection.git/'

# %%
# !ssh-keygen -t rsa -b 4096 -C "aniket.iitism@gmail.com"
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa):
# Created directory '/root/.ssh'.
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /root/.ssh/id_rsa
# Your public key has been saved in /root/.ssh/id_rsa.pub
# The key fingerprint is:
# SHA256:z0BwyR0smTxv+t8sEg5+XXT7boCzUn3J+iPoHbs+RPs aniket.iitism@gmail.com
# The key's randomart image is:
# +---[RSA 4096]----+
# |      .o.*..     |
# |       oO o      |
# |        .+       |
# |       .  o  .. .|
# |        So  .+o.o|
# |        o+. +o++.|
# |       . +o+o=oo.|
# |        . *.=*oEo|
# |         ..=o*B+o|
# +----[SHA256]-----+

# %%
# !eval "$(ssh-agent -s)"
# !ssh-add ~/.ssh/id_rsa
# Out:
# Agent pid 74938
# Could not open a connection to your authentication agent.

# %%
# !cat ~/.ssh/id_rsa.pub
# Out:
# ssh-rsa ... aniket.iitism@gmail.com

# %%
# !git remote set-url origin git@github.com:dwivedi1997/Number-Plate-Detection.git

# %%
# !git push -u origin main
# Out:
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !ssh-keygen -R github.com
# Out:
# Cannot stat /root/.ssh/known_hosts: No such file or directory
